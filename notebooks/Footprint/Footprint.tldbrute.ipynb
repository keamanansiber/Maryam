# %%
# !maryam -e tldbrute --help
# Out:
# usage: tldbrute [-h] -d DOMAIN [-c COUNT] [-w WORDLIST] [-t THREAD] [-i]
#                 [--output] [--api] [--format]
#
# tldbrute 1.1(Saeed) - description: TLD brute force attack, supports
# cocurrency.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain name without https?://
#   -c COUNT, --count COUNT
#                         Number of payloads len(max=count of payloads). default
#                         is max
#   -w WORDLIST, --wordlist WORDLIST
#                         wordlist address. default is dnsnames.txt in data
#                         folder
#   -t THREAD, --thread THREAD
#                         The number of links that open per round(default=8)
#   -i, --ips             Show ip addresses
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
# ...

# %%
# !maryam -e tldbrute -d ibm.com
# Out:
# ------------------------------------------
# STARTING TLD BRUTE FORCE WITH 1527 PAYLOAD
# ------------------------------------------
# [*] ibm.af
# [*] ibm.ai
# [*] ibm.am
# [*] ibm.ac => Timed out
# [*] ibm.africa => Timed out
# [*] ibm.asia
# [*] ibm.at
# [*] ibm.bar
# [*] ibm.be
# [*] ibm.biz
# [*] ibm.bi
# [*] ibm.bg
# [*] ibm.bo
# [*] ibm.bs
# [*] ibm.buzz
# [*] ibm.bz
# [*] ibm.ca
# [*] ibm.by
# [*] ibm.career
# [*] ibm.ceo
# [*] ibm.cd
# [*] ibm.cat
# [*] ibm.cg
# [*] ibm.ch
# [*] ibm.ci
# [*] ibm.cloud
# [*] ibm.cm
# [*] ibm.cl
# [*] ibm.co
# [*] ibm.cn
# [*] ibm.com
# [*] ibm.courses
# [*] ibm.cz
# [*] ibm.de
# [*] ibm.dev
# [*] ibm.cx => Timed out
# [*] ibm.dk
# [*] ibm.dm
# [*] ibm.design => Timed out
# [*] ibm.ee
# [*] ibm.es
# [*] ibm.eu
# [*] ibm.earth => Timed out
# [*] ibm.fi
# [*] ibm.fm
# [*] ibm.feedback => Timed out
# [*] ibm.fr
# [*] ibm.global
# [*] ibm.gd
# [*] ibm.gg
# [*] ibm.gl
# [*] ibm.gm
# [*] ibm.health
# [*] ibm.gr
# [*] ibm.hk
# [*] ibm.hu
# ...

# %%
# !maryam -e tldbrute -d its.ac.id -i --output
# Out:
# ------------------------------------------
# STARTING TLD BRUTE FORCE WITH 1527 PAYLOAD
# ------------------------------------------
# [*] ac.ac : 13.225.94.34
# [*] ac.af : 104.21.88.99
# [*] ac.agency : 52.72.49.79
# [*] ac.al : 216.120.146.201
# [*] ac.amsterdam : 3.64.163.50
# [*] ac.ax : 185.53.177.51
# [*] ac.asia => Timed out
# [*] ac.baby => Timed out
# [*] ac.bz : 64.190.63.111
# [*] ac.cab : 52.178.190.191
# [*] ac.beer => Timed out
# [*] ac.biz => Timed out
# [*] ac.chat : 35.201.238.84
# [*] ac.cl : 64.190.63.111
# [*] ac.capital => Timed out
# [*] ac.casa => Timed out
# [*] ac.coach : 209.99.64.33
# [*] ac.cz : 217.11.242.117
# [*] ac.co => Timed out
# [*] ac.consulting => Timed out
# [*] ac.cooking => Timed out
# [*] ac.digital : 3.64.163.50
# [*] ac.cx => Timed out
# [*] ac.deals => Timed out
# [*] ac.dk : 93.191.156.216
# [*] ac.direct => Timed out
# [*] ac.energy : 35.208.241.140
# [*] ac.dj : 46.8.8.100
# [*] ac.ee : 3.64.163.50
# [*] ac.doctor => Timed out
# ...

# %%
# !maryam -e tldbrute -d keamanansiber.id -i --output --api --format
# Out:
# {
#     "hostnames": [
#         "keamanansiber.id : 103.147.154.45",
#         "keamanansiber.vg : 88.198.29.97"
#     ],
#     "running_errors": []
# }
