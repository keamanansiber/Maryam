# %%
# !maryam -e crawler --help
# Out:
# usage: crawler [-h] -d DOMAIN [--debug] [-l LIMIT] [-t THREAD] [--output]
#                [--api] [--format]
#
# crawler 0.5(Saeed) - description: Crawl web pages to find links, JS Files, CSS
# files, Comments and everything else interesting, supports concurrency.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain string
#   --debug, --debug      debug the scraper
#   -l LIMIT, --limit LIMIT
#                         Scraper depth level
#   -t THREAD, --thread THREAD
#                         The number of links that open per round
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e crawler -d its.ac.id
# Out:
# [*] js(13)
# [*] 	https://www.its.ac.id/wp-includes/js/jquery/jquery-migrate.min.js
# [*] 	https://www.its.ac.id/wp-includes/js/jquery/jquery.min.js
# [*] 	https://www.its.ac.id/wp-content/plugins/prevent-xss-vulnerability/frontend/js/script-1.0.0.min.js
# [*] 	https://www.its.ac.id/wp-content/plugins/js_composer/assets/lib/vc_tabs/vc-tabs.min.js
# [*] 	https://www.its.ac.id/wp-content/themes/ITS/assets/js/imagesloaded.pkgd.min.js
# [*] 	https://www.its.ac.id/wp-content/plugins/js_composer/assets/lib/vc-tta-autoplay/vc-tta-autoplay.min.js
# [*] 	https://www.its.ac.id/wp-content/themes/ITS/assets/js/masonry.pkgd.min.js
# [*] 	https://www.its.ac.id/wp-content/themes/ITS/assets/js/bootstrap.min.js
# [*] 	https://www.its.ac.id/wp-content/plugins/its-dosen/js/vue.min.js
# [*] 	https://www.its.ac.id/wp-content/plugins/js_composer/assets/js/dist/js_composer_front.min.js
# [*] 	https://www.its.ac.id/wp-content/plugins/js_composer/assets/lib/vc_accordion/vc-accordion.min.js
# ...

# %%
# !maryam -e crawler -d keamanansiber.id --output --api --format
# Out:
# {
#     "js": [
#         "https://keamanansiber.id/wp-content/plugins/super-socializer/js/front/social_login/general.js?ver=7.12.44",
#         "https://keamanansiber.id///keamanansiber.id/wp-includes/js/wp-emoji-release.min.js?ver=5.4.10",
#         "https://keamanansiber.id/wp-content/themes/colormag/js/fitvids/jquery.fitvids.js?ver=20150311",
#         "https://keamanansiber.id/wp-content/plugins/super-socializer/js/front/facebook/commenting.js?ver=7.12.44",
#         "https://keamanansiber.id/wp-content/themes/colormag/js/colormag-custom.js?ver=5.4.10",
#         "https://keamanansiber.id/wp-content/themes/colormag/js/jquery.bxslider.min.js?ver=4.2.10",
#         "https://keamanansiber.id/wp-content/themes/colormag/js/navigation.js?ver=5.4.10",
#         "https://keamanansiber.id/wp-content/plugins/super-socializer/js/front/social_login/common.js?ver=7.12.44",
#         "https://keamanansiber.id/wp-content/plugins/super-socializer/js/front/facebook/sdk.js?ver=7.12.44",
# ...
