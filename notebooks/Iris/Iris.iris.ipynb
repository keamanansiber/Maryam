# %%
# !maryam -e iris --help
# Out:
# usage: iris [-h] -q QUERY [--output] [--api] [--format]
#
# iris 0.4(Saeed, Kaushik) - description: Iris is a built-in meta search engine.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e iris -q marvel
# Out:
# [*] [GOOGLE] Searching in 1 page...
# [*] [BING] Searching in 1 page...
# [*] [DuckDuckGo] Searching in 1 page...
# [*] [MILLIONSHORT] Searching in 1 page...
# [*] [YAHOO] Searching in 1 page...
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 1...
# [!] [util/engines/millionshort:run_crawl] CaptchaError.
# [!] [util/engines/millionshort:name_crawl] Millionshort is missed!
# [*] [GOOGLE] Searching in 2 page...
# [*] [YAHOO] Searching in 2 page...
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 2...
# [*] [GOOGLE] Searching in 3 page...
# [*] [YAHOO] Searching in 3 page...
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 3...
# [*] マーベル公式｜Marvel
# [*] https://marvel.disney.co.jp/
# [*] https://marvel.disney.co.jp
# [*] オーディオテクニカから『アベンジャーズ／エンドゲーム』の世界的大ヒットも記憶に新しいMARVELのオリジナル完全ワイヤレスイヤホン第2弾が登場。 第2弾は、完全新作 ...Amazon： e☆イヤホンケーズデンキ： 上新電機東急ハンズ： ノジマ
#
# [*] キャラクター紹介 - マーベル公式｜Marvel
# [*] https://marvel.disney.co.jp/character.html
# ...

# %%
# !maryam -e iris -q suryotrisongko --output
# Out:
# [*] [GOOGLE] Searching in 1 page...
# [*] [BING] Searching in 1 page...
# [*] [DuckDuckGo] Searching in 1 page...
# [*] [MILLIONSHORT] Searching in 1 page...
# [*] [YAHOO] Searching in 1 page...
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 1...
# [!] [util/engines/millionshort:run_crawl] CaptchaError.
# [!] [util/engines/millionshort:name_crawl] Millionshort is missed!
# [*] [GOOGLE] Searching in 2 page...
# [*] [YAHOO] Searching in 2 page...
# [*] [GOOGLE] Searching in 3 page...
# [*] [YAHOO] Searching in 3 page...
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 2...
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 3...
# [*] Yasuo Musashi - My portal - researchmap
# [*] https://researchmap.jp/yasuo.musashi?lang=en
# [*] https://researchmap.jp › yasuo.musashi
# ...

# %%
# !maryam -e iris -q suryotrisongko --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "Yasuo Musashi - My portal - researchmap",
#             "a": "https://researchmap.jp/yasuo.musashi?lang=en",
#             "c": "https://researchmap.jp \u203a yasuo.musashi",
#             "d": "Siddhartha Bhattacharyya, \u200eJanmenjoy Nayak, \u200eKolla Bhanu Prakash \u00b7 2021 \u00b7 \u200eTechnology & EngineeringFakhruzzaman MN, Riksakomara E, Suryotrisongko H (2015) EEG wave identifcation in human brain with emotiv epoc for motor imagery. Proc Comput Sci 72:269\u2013276\u00a0..."
#         },
#         {
#             "t": "\u6b66\u85cf \u6cf0\u96c4 (Yasuo Musashi) - \u30de\u30a4\u30dd\u30fc\u30bf\u30eb - researchmap",
#             "a": "https://researchmap.jp/yasuo.musashi",
#             "c": "https://researchmap.jp \u203a yasuo.musashi",
# ...
