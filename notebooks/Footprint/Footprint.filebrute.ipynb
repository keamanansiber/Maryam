# %%
# !maryam -e filebrute --help
# Out:
# usage: filebrute [-h] [-d DOMAIN] [-c COUNT] [-w WORDLIST] [-t THREAD] [-l]
#                  [-s STATUS_CODES] [-r] [--output] [--api] [--format]
#
# filebrute 1.0(Saeed) - description: File/Directory brute force attack,
# supports cocurrency.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain name without https?://
#   -c COUNT, --count COUNT
#                         Number of payloads len(max=count of payloads). default
#                         is max
#   -w WORDLIST, --wordlist WORDLIST
#                         wordlist address. default is dnsnames.txt in data
#                         folder
#   -t THREAD, --thread THREAD
#                         The number of links that open per round(default=8)
#   -l, --wordlists       List of most common DNS wordlists
#   -s STATUS_CODES, --status_codes STATUS_CODES
#                         List of good status codes(default="200,201,204")
# ...

# %%
# !maryam -e filebrute
# Out:
# usage: filebrute [-h] [-d DOMAIN] [-c COUNT] [-w WORDLIST] [-t THREAD] [-l]
#                  [-s STATUS_CODES] [-r] [--output] [--api] [--format]
#
# filebrute 1.0(Saeed) - description: File/Directory brute force attack,
# supports cocurrency.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain name without https?://
#   -c COUNT, --count COUNT
#                         Number of payloads len(max=count of payloads). default
#                         is max
#   -w WORDLIST, --wordlist WORDLIST
#                         wordlist address. default is dnsnames.txt in data
#                         folder
#   -t THREAD, --thread THREAD
#                         The number of links that open per round(default=8)
#   -l, --wordlists       List of most common DNS wordlists
#   -s STATUS_CODES, --status_codes STATUS_CODES
#                         List of good status codes(default="200,201,204")
# ...

# %%
# !maryam -e filebrute -d ibm.com
# Out:
# ----------------------------------------------
# STARTING FILE/DIR BRUTE FORCE WITH 499 PAYLOAD
# ----------------------------------------------
# [*] http://ibm.com/search/
# [*] http://ibm.com/
# [*] http://ibm.com/images/
# [*] http://ibm.com/index.php
# [*] http://ibm.com/include
# [*] http://ibm.com/search
# [*] http://ibm.com/?q=user/register/
# [*] http://ibm.com/?q=user/password/
# [*] http://ibm.com/?q=node/add/
# [*] http://ibm.com/?q=user/login/
# [*] http://ibm.com/?q=comment/reply/
# [*] http://ibm.com/?q=search/
# [*] http://ibm.com/?q=admin/
# [*] http://ibm.com/community/
# [*] http://ibm.com/download/ => Timed out
# [*] http://ibm.com/services/
# [*] http://ibm.com/include/
# [*] http://ibm.com/contact/
# [*] http://ibm.com/?q=user/logout/
# [*] http://ibm.com/?q=filter/tips/
# [*] http://ibm.com/?level=12
# [*] http://ibm.com/
# [*] http://ibm.com/z/
# [*] http://ibm.com?&what=
# [*] http://ibm.com/xml/
# [*] http://ibm.com/services
# ...

# %%
# !maryam -e filebrute -d its.ac.id --output
# Out:
# ----------------------------------------------
# STARTING FILE/DIR BRUTE FORCE WITH 499 PAYLOAD
# ----------------------------------------------
# [*] http://its.ac.id/api/
# [*] http://its.ac.id/
# [*] http://its.ac.id/template/
# [*] http://its.ac.id/search/
# [*] http://its.ac.id/wp-admin/
# [*] http://its.ac.id/data/
# [*] http://its.ac.id/admin/
# [*] http://its.ac.id/admin
# [*] http://its.ac.id/member/
# [*] http://its.ac.id/index.php
# [*] http://its.ac.id/language/
# [*] http://its.ac.id/search
# [*] http://its.ac.id/page/
# [*] http://its.ac.id/lib/
# [*] http://its.ac.id/?q=user/password/
# [*] http://its.ac.id/?q=user/register/
# [*] http://its.ac.id/?q=node/add/
# [*] http://its.ac.id/?q=user/login/
# [*] http://its.ac.id/?q=search/
# [*] http://its.ac.id/?q=comment/reply/
# [*] http://its.ac.id/?q=admin/
# [*] http://its.ac.id/wp-content/themes
# [*] http://its.ac.id/wp-content/plugins
# [*] http://its.ac.id/wp-admin
# [*] http://its.ac.id/community/
# ...

# %%
# !maryam -e filebrute -d keamanansiber.id --output --api --format
# Out:
# {
#     "urls": [
#         "http://keamanansiber.id/",
#         "http://keamanansiber.id/wp-admin/",
#         "http://keamanansiber.id/admin/",
#         "http://keamanansiber.id/admin",
#         "http://keamanansiber.id/index.php",
#         "http://keamanansiber.id/?q=user/register/",
#         "http://keamanansiber.id/?q=user/login/",
#         "http://keamanansiber.id/?q=user/password/",
#         "http://keamanansiber.id/wp-content/themes",
#         "http://keamanansiber.id/?q=search/",
#         "http://keamanansiber.id/wp-content/plugins",
#         "http://keamanansiber.id/?q=comment/reply/",
#         "http://keamanansiber.id/?q=node/add/",
#         "http://keamanansiber.id/?q=admin/",
#         "http://keamanansiber.id/wp-admin",
#         "http://keamanansiber.id/wp-content/cache",
#         "http://keamanansiber.id/login/",
#         "http://keamanansiber.id/?q=filter/tips/",
#         "http://keamanansiber.id/?q=user/logout/",
#         "http://keamanansiber.id/",
# ...
