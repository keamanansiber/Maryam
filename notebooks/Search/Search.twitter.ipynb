# %%
# !maryam -e twitter --help
# Out:
# usage: twitter [-h] -q QUERY [-l LIMIT] [-c COUNT] [-t THREAD] [-e ENGINE]
#                [--output] [--api] [--format]
#
# twitter 0.5(Saeed) - description: Search your query in the twitter.com and
# show the results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=1)
#   -c COUNT, --count COUNT
#                         The number of results per page(min=10, max=100,
#                         default=50)
#   -t THREAD, --thread THREAD
#                         The number of engine that run per round(default=2)
#   -e ENGINE, --engine ENGINE
#                         Engine names for search(default=google)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e twitter -q cybersecurity
# Out:
# [*] [GOOGLE] Searching in 1 page...
# [*] LINKS
# [*] 	Without result
# [*] PEOPLE
# [*] 	dccybersecurity\\u0026tbm\\u003dilp\\u00
# [*] 	airbuscyber 22
# [*] 	cyberfrat\\u0026tbm\\u003dilp\\u0026ilps
# [*] 	cybersecurityn8 22
# [*] 	dccybersecurity
# [*] 	cybersecdive 22]]
# [*] 	mitigogroup 22
# [*] 	seceduau 22
# [*] 	cisagov
# [*] 	fticyber 22]]
# [*] 	cybersecinsider 22]]
# [*] 	nistcyber\\u0026tbm\\u003dilp\\u0026ilps
# [*] 	infosec_review\\u0026tbm\\u003dilp\\u002
# [*] 	bcncybercon\\u0026tbm\\u003dilp\\u0026il
# [*] 	gcsec\\u0026tbm\\u003dilp\\u0026ilps\\u0
# [*] 	luxsecurityweek 22
# [*] 	nistcyber 22
# [*] 	airbuscyber
# [*] 	gcfriyadh
# [*] 	fticyber\\u0026tbm\\u003dilp\\u0026ilps\
# [*] 	wefcybersec\\u0026tbm\\u003dilp\\u0026il
# [*] 	scsdays\\u0026tbm\\u003dilp\\u0026ilps\\
# [*] 	cybersecmonth 22
# [*] 	cybersecurityn8 22]]
# [*] 	womencssociety 22
# [*] 	versprite\\u0026tbm\\u003dilp\\u0026ilps
# [*] 	staysafeonline 22]]
# [*] 	versprite 22]]
# [*] 	cybersecinsider
# ...

# %%
# !maryam -e twitter -q suryotrisongko --output --api --format
# Out:
# {
#     "links": [],
#     "people": [
#         "suryotrisongko\\x22",
#         "ChristophMolnar",
#         "hashtag",
#         "mhusni43\\\\u0026tbm\\\\u003dilp\\\\u0026ilps\\",
#         "mhusni43\\x22",
#         "suryotrisongko",
#         "ftmmunair",
#         "mhusni43\\x22]]",
#         "mhusni43",
#         "suryotrisongko\\x22]]",
#         "suryotrisongko\\\\u0026tbm\\\\u003dilp\\\\u002"
#     ],
#     "hashtags": [],
#     "running_errors": []
# }
