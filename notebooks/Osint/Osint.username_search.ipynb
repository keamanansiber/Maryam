# %%
# !maryam -e username_search --help
# Out:
# usage: username_search [-h] -q QUERY [-t THREAD] [--output] [--api] [--format]
#
# username_search 0.5(Aman Singh) - description: Search your query across 100+
# social networks and show the results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -t THREAD, --thread THREAD
#                         The number of sites that are being checked per
#                         round(default=8)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e username_search -q cybersecurity
# Out:
# Found 131 accounts
#
# [*] Accounts Found (sorted by site's rank)
#
#   +_______________________________________________________________________________________________________________+
#   |             Site            |                                     Account                                     |
#   +_______________________________________________________________________________________________________________+
#   | WordPress Support           | https://wordpress.org/support/users/cybersecurity/                              |
#   +_______________________________________________________________________________________________________________+
#   | Pinterest                   | https://www.pinterest.com/cybersecurity/                                        |
#   +_______________________________________________________________________________________________________________+
# ...

# %%
# !maryam -e username_search -q suryotrisongko --output --api --format
# Out:
# {
#     "links": [
#         [
#             "YouTube",
#             {
#                 "url": "https://www.youtube.com/user/suryotrisongko/videos",
#                 "rank": "5"
#             }
#         ],
#         [
#             "WordPress Support",
#             {
#                 "url": "https://wordpress.org/support/users/suryotrisongko/",
#                 "rank": "15"
#             }
#         ],
#         [
#             "Wikipedia",
#             {
#                 "url": "https://en.wikipedia.org/wiki/User:suryotrisongko",
#                 "rank": "19"
#             }
#         ],
#         [
#             "Reddit",
#             {
#                 "url": "https://www.reddit.com/user/suryotrisongko",
#                 "rank": "39"
#             }
#         ],
#         [
#             "Medium",
#             {
#                 "url": "https://medium.com/@suryotrisongko",
#                 "rank": "55"
#             }
#         ],
#         [
# ...
