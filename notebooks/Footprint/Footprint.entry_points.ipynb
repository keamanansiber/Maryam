# %%
# !maryam -e entry_points --help
# Out:
# usage: entry_points [-h] -d DOMAIN [--debug] [-l LIMIT] [-t THREAD] [--output]
#                     [--api] [--format]
#
# entry_points 0.1(Saeed) - description: Crawl web pages to find entry
# points(inputs, urls with param).
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain string
#   --debug, --debug      debug the scraper
#   -l LIMIT, --limit LIMIT
#                         Scraper depth level
#   -t THREAD, --thread THREAD
#                         The number of links that open per round
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e entry_points -d ibm.com
# Out:
# [*] FORMS
# {
#     "0": {
#         "form": {
#             "action": "https://www.ibm.com/Search/",
#             "method": "get"
#         },
#         "inputs": {
#             "text": [
#                 {
#                     "maxlength": "100",
#                     "name": "q",
#                     "type": "text",
#                     "value": ""
#                 }
#             ],
#             "hidden": [
#                 {
#                     "name": "v",
#                     "type": "hidden",
#                     "value": "18"
#                 },
#                 {
#                     "name": "en",
#                     "type": "hidden",
#                     "value": "utf"
#                 },
#                 {
#                     "name": "lang",
#                     "type": "hidden",
#                     "value": "ko"
#                 },
#                 {
#                     "name": "cc",
#                     "type": "hidden",
# ...

# %%
# !maryam -e entry_points -d its.ac.id --debug -l 3 --output
# Out:
# [*] https://www.its.ac.id/study-at-its/
# [*] https://www.its.ac.id/campus-life/theres-always-something-interesting/
# [*] https://www.its.ac.id/research/research-focus/
# [*] https://bahasa.its.ac.id/
# [*] https://www.its.ac.id/industry/workforce-development/
# [*] https://www.its.ac.id/research/research-publications/
# [*] https://www.its.ac.id/international/experiencing-its/prospective-student/admission/full-degree/
# [*] https://www.its.ac.id/gpr/
# [*] https://www.its.ac.id/research/research-collaborations/
# [*] https://www.its.ac.id/campus-life/student-activities/
# [*] https://www.its.ac.id/about-its/visit-its/
# [*] https://www.its.ac.id/wp-content/cache/autoptimize/1/autoptimize_c83c1608f7470fbc31e2ca657e4707dc.php
# [*] https://www.its.ac.id/id/beranda/
# [*] https://www.its.ac.id/admission/sarjana-terapan/
# [*] https://www.its.ac.id/wp-content/cache/autoptimize/1/autoptimize_single_730e28c14f5c323bbc5cd399f59877cb.php
# [*] https://www.its.ac.id/
# ...

# %%
# !maryam -e entry_points -d keamanansiber.id --debug -l 1 --output --api --format
# Out:
# {
#     "params": {
#         "https://keamanansiber.id/wp-content/plugins/super-socializer/css/front.css": {
#             "ver": "7.12.44"
#         },
#         "https://keamanansiber.id/wp-content/themes/colormag/js/navigation.js": {
#             "ver": "5.4.10"
#         },
#         "https://keamanansiber.id/wp-content/plugins/super-socializer/js/front/facebook/sdk.js": {
#             "ver": "7.12.44"
#         },
#         "https://keamanansiber.id/wp-content/uploads/2020/07/KonsepDasarQuantumComputingSlide1-800x445.png": {
#             "is-pending-load": "1"
#         },
#         "https://keamanansiber.id/wp-content/uploads/2020/07/MatlabAndOctave-800x445.png": {
#             "is-pending-load": "1"
#         },
#         "https://keamanansiber.id/wp-content/uploads/2020/06/QuantumComputingBooksForBabies-800x445.jpg": {
#             "is-pending-load": "1"
#         },
#         "https://keamanansiber.id/xmlrpc.php": {
#             "rsd": ""
#         },
# ...
