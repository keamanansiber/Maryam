# %%
# !maryam -e duckduckgo --help
# Out:
# usage: duckduckgo [-h] -q QUERY [-c COUNT] [--output] [--api] [--format]
#
# duckduckgo 0.1(Tarunesh Kumar) - description: Search your query in the
# duckduckgo.com and show the results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -c COUNT, --count COUNT
#                         Number of results per page(min=10, max=100,
#                         default=50)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e duckduckgo -q cybersecurity
# Out:
# [*] [DuckDuckGo] Searching in 1 page...
# [*] What is Cybersecurity? | IBM
# [*] //duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.ibm.com%2Ftopics%2Fcybersecurity&rut=f3347928f6d8f5a1877cbb64cc9ed842d7af802c62f735d3d3f9ed8b6c41c91d
# [*] ://duckduckgo.com › l
# [*] Cybersecurity is the practice of protecting critical systems and sensitive information from digital attacks. Also known as information technology (IT) security, cybersecurity measures are designed to combat threats against networked systems and applications, whether those threats originate from inside or outside of an organization. In 2020, the average cost of a data breach was USD 3.86 ...
#
# [*] What is Cybersecurity? | CISA
# [*] //duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.cisa.gov%2Fuscert%2Fncas%2Ftips%2FST04%2D001&rut=711e214e756e66a3bb1e81205205790cf0adf016cff1f72d9ace64ca69a4b412
# [*] ://duckduckgo.com › l
# ...

# %%
# !maryam -e duckduckgo -q suryotrisongko --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "GitHub - suryotrisongko/wp-association-membership-management-software ...",
#             "a": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2Fsuryotrisongko%2Fwp%2Dassociation%2Dmembership%2Dmanagement%2Dsoftware&rut=41d32f7cd3750e6c0d0630ece0926479e39da6a5302d06e3c0344d6c8afce9e9",
#             "c": "://duckduckgo.com \u203a l",
#             "d": "Launching Visual Studio Code. Your codespace will open once ready. There was a problem preparing your codespace, please try again."
#         },
#         {
#             "t": "Hatma Suryotrisongko (@suryotrisongko) - WordPress user profile",
#             "a": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fprofiles.wordpress.org%2Fsuryotrisongko%2F&rut=60a081820a7eec99c7426a8e821ea11ddea54ffb76500fa7e9887e651a21218d",
#             "c": "://duckduckgo.com \u203a l",
# ...
