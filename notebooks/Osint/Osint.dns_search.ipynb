# %%
# !maryam -e dns_search --help
# Out:
# usage: dns_search [-h] [-d DOMAIN] [-l LIMIT] [-c COUNT] [-e ENGINES]
#                   [-t THREAD] [--max] [--validate] [--silent] [-r REVERSE]
#                   [--output] [--api] [--format]
#
# dns_search 2.5(Saeed) - description: Search in the open-sources to find
# subdomans.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain name without https?://
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=3)
#   -c COUNT, --count COUNT
#                         number of results per page(min=10, max=100,
#                         default=30)
#   -e ENGINES, --engines ENGINES
#                         Search engine names. e.g bing,google,...[otx by
#                         default]
#   -t THREAD, --thread THREAD
#                         The number of engine that run per round(default=2)
# ...

# %%
# !maryam -e dns_search
# Out:
# usage: dns_search [-h] [-d DOMAIN] [-l LIMIT] [-c COUNT] [-e ENGINES]
#                   [-t THREAD] [--max] [--validate] [--silent] [-r REVERSE]
#                   [--output] [--api] [--format]
#
# dns_search 2.5(Saeed) - description: Search in the open-sources to find
# subdomans.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DOMAIN, --domain DOMAIN
#                         Domain name without https?://
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=3)
#   -c COUNT, --count COUNT
#                         number of results per page(min=10, max=100,
#                         default=30)
#   -e ENGINES, --engines ENGINES
#                         Search engine names. e.g bing,google,...[otx by
#                         default]
#   -t THREAD, --thread THREAD
#                         The number of engine that run per round(default=2)
# ...

# %%
# !maryam -e dns_search -d ibm.com
# Out:
# [*] [OTX] Searching in otx.alienvault...
# [*] [SECTRAILS] Enumerating dns records...
# [!] [dns_search:otx] OTX is missed!
# [*] HOSTNAMES
# [*] 	Without result

# %%
# !maryam -e dns_search -d ibm.com --output --api --format
# Out:
# {
#     "hostnames": [
#         "b.27522310.jp-osa.e2e.certificate-manager.test.cloud.ibm.com",
#         "28522010.dev.e2e.certificate-manager.test.cloud.ibm.com",
#         "consumer.e113-138dccd9.us-south.ri-dev.apic.test.cloud.ibm.com",
#         "2752237.us-south.e2e.certificate-manager.test.cloud.ibm.com",
#         "27522310.jp-tok.e2e.certificate-manager.test.cloud.ibm.com",
#         "2752230.ca-tor.e2e.certificate-manager.test.cloud.ibm.com",
#         "s.2752231.au-syd.e2e.certificate-manager.test.cloud.ibm.com",
#         "2752231.eu-de.e2e.certificate-manager.test.cloud.ibm.com",
#         "ns092.name.cloud.ibm.com",
#         "2752227.preprod.e2e.certificate-manager.test.cloud.ibm.com",
#         "2752235.ca-tor.e2e.certificate-manager.test.cloud.ibm.com",
#         "sandbox.eu.maximomro.ibmiot.ibm.com",
#         "2752236.eu-gb.e2e.certificate-manager.test.cloud.ibm.com",
#         "27522312.preprod.e2e.certificate-manager.test.cloud.ibm.com",
# ...
