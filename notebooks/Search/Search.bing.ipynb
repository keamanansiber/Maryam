# %%
# !maryam -e bing --help
# Out:
# usage: bing [-h] -q QUERY [-l LIMIT] [-c COUNT] [--output] [--api] [--format]
#
# bing 0.1(Saeed) - description: Search your query in the bing.com and show the
# results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=1)
#   -c COUNT, --count COUNT
#                         Number of results per page(min=10, max=100,
#                         default=50)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e bing -q cybersecurity
# Out:
# [*] [BING] Searching in 1 page...
# [*] What is Cybersecurity? | IBM
# [*] https://www.bing.com/ck/a?!&&p=28581458f5f6ed73de2b20000fbef81b912e7c57c93192b3766656556e2e6a86JmltdHM9MTY1MzcyMDE5OCZpZ3VpZD1kNjM3NzVkMC00N2ZhLTQyZGItYjBmMC00YTlkY2VjOTliY2UmaW5zaWQ9NTIyNg&ptn=3&fclid=74d4eb32-de51-11ec-9cb3-440c9b9a7b0b&u=a1aHR0cHM6Ly93d3cuaWJtLmNvbS90b3BpY3MvY3liZXJzZWN1cml0eQ&ntb=1
# [*] https://www.ibm.com › topics › cybersecur
# [*] Cybersecurity is the practice of protecting critical systems and sensitive information from digital attacks. Also known as information technology (IT) security, cybersecurity measures are designed to combat threats against networked systems and applications, whether those threats originate from inside or outside of an organization. In 2020, the average cost of a data breach …
#
# [*] What Is Cybersecurity? - Cisco
# ...

# %%
# !maryam -e bing -q suryotrisongko --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "suryotrisongko \u2013 PPI Jepang Kumamoto",
#             "a": "https://www.bing.com/ck/a?!&&p=9fbf7d801dc8eae117f1b48c2ba07e1810e5b4059712423a654d12f9cd7d985dJmltdHM9MTY1MzcyMDIwMiZpZ3VpZD04NDljMTU3Yy02YzNlLTQzOTktOTUyOC0xNmI2YmEwNDQ3ZjcmaW5zaWQ9NTE3Ng&ptn=3&fclid=778170d9-de51-11ec-98ce-ce52207f2fb3&u=a1aHR0cHM6Ly9wcGlqLWt1bWFtb3RvLm9yZy9hdXRob3Ivc3VyeW90cmlzb25na28v&ntb=1",
#             "c": "https://ppij-kumamoto.org \u203a author \u203a suryotriso",
#             "d": "suryotrisongko. Berita Menikmati Camping, Bbq, Air Terjun dan Pemandangan di Bumi Beruang Hitam. Banyak yang mimpi pengen punya pengalaman camping, tapi di Indonesia nggak ada temannya, atau mungkin khawatir masalah keamanan, atau \u2026"
#         },
#         {
#             "t": "Profil Hatma Suryotrisongko - Departemen Sistem Informasi",
# ...
