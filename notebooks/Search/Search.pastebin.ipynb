# %%
# !maryam -e pastebin --help
# Out:
# usage: pastebin [-h] -q QUERY [-l LIMIT] [-c COUNT] [--output] [--api]
#                 [--format]
#
# pastebin 1.1(Divya Goswami) - description: Search your query in the
# pastebin.com and show the results as paste links.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=1)
#   -c COUNT, --count COUNT
#                         Number of results per page(min=10, max=100,
#                         default=50)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e pastebin -q cybersecurity
# Out:
# [*] [GOOGLE] Searching in 1 page...
# [*] [BING] Searching in 1 page...
# [*] [YAHOO] Searching in 1 page...
# [*] [ASK] Searching in 0 page...
# [*] [DuckDuckGo] Searching in 1 page...
# [*] [MILLIONSHORT] Searching in 1 page...
# [!] [util/carrot2:run_crawl] ETOOLS is missed!
# [*] [QWANT] Searching in 2 page...
# [!] [util/engines/millionshort:run_crawl] CaptchaError.
# [!] [util/engines/millionshort:name_crawl] Millionshort is missed!
# [*] Rearranging paste links [give it a few seconds]...
# [*] Cybersecurity Pastes # Subject...
# [*] 	https://pastebin.com/Mya5PEF1
# [*] Cybersecurity Pastes /Cyb/ + /Sec/ - Cyberpunk/Cybe...
# [*] 	https://pastebin.com/6XpnakP8
# [*] Cybersecurity Pastes <Html>...
# [*] 	https://pastebin.com/Gnx1m4E2
# [*] Cybersecurity Pastes ...
# [*] 	https://pastebin.com/BZZpKU2Q
# [*] Cybersecurity Pastes Https://Www.Newsweek.Com/Chine...
# [*] 	https://pastebin.com/aAKPdWXW
# [*] Cybersecurity Pastes <!Doctype Html>...
# [*] 	https://pastebin.com/diff
# ...

# %%
# !maryam -e pastebin -q hatma --output --api --format
# Out:
# {
#     "pastes": [
#         [
#             "https://pastebin.com/TM0rnkdZ",
#             "Hatma Pastes Ilmu Hukum Ugm..."
#         ],
#         [
#             "https://pastebin.com/SMJwt7Uk",
#             "Hatma Pastes Katika Moja Ya Barua Pepe Za K..."
#         ],
#         [
#             "https://pastebin.com/N5ti4tBr",
#             "Hatma Pastes Usiku Mwema. Juu Ya Krismasi, ..."
#         ],
#         [
#             "https://pastebin.com/bRLKKyM3",
#             "Hatma Pastes 2019-09-12 21:11:34.9928|Debug..."
#         ],
#         [
#             "https://pastebin.com/Lp8K3pec",
#             "Hatma Pastes Rw Xosh..."
#         ]
#     ],
#     "running_errors": [
#         "[util/carrot2:run_crawl] ETOOLS is missed!",
#         "[util/duckduckgo:run_crawl] 403 Forbidden.",
#         "[util/duckduckgo:run_crawl] DuckDuckGo is missed!",
#         "[util/engines/millionshort:run_crawl] CaptchaError.",
# ...
