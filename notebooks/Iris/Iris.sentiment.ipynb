# %%
# !maryam -e bing -q russia -l 4 --api --format > russia.json

# %%
# !cat russia.json
# Out:
# {
#     "results": [
#         {
#             "t": "\u30ed\u30b7\u30a2 - Wikipedia",
#             "a": "https://www.bing.com/ck/a?!&&p=49700bc36f35d9ea6c635b546a172314a47805dd0ffda02d72902f569992a0f4JmltdHM9MTY1MzczMTE5NiZpZ3VpZD0xMTZmMGVkMi01ZmQ5LTQ1M2ItODY3OC02OGNhYWFjNWU5ZjUmaW5zaWQ9NTIxMg&ptn=3&fclid=103480b4-de6b-11ec-b7f6-b401fde992af&u=a1aHR0cHM6Ly9qYS53aWtpcGVkaWEub3JnL3dpa2kvJUUzJTgzJUFEJUUzJTgyJUI3JUUzJTgyJUEy&ntb=1",
#             "c": "https://ja.wikipedia.org \u203a wiki \u203a \u30ed\u30b7\u30a2",
# ...

# %%
# !maryam -e sentiment --help
# Out:
# usage: sentiment [-h] [-j JSON] [-k KEY] [-t THREAD] [-p] [--output] [--api]
#                  [--format]
#
# sentiment 0.1(Saeed) - description: Running sentiment analysis on your data.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -j JSON, --json JSON  Json file that contains the data
#   -k KEY, --key KEY     Data key. the value should be a list. None means the
#                         json file contains a list: ["..", ..]
#   -t THREAD, --thread THREAD
#                         The number of thread per each sell(default=10)
#   -p, --pipe            Dev only! pipe data from other modules(default=False)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e sentiment
# Out:
# usage: sentiment [-h] [-j JSON] [-k KEY] [-t THREAD] [-p] [--output] [--api]
#                  [--format]
#
# sentiment 0.1(Saeed) - description: Running sentiment analysis on your data.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -j JSON, --json JSON  Json file that contains the data
#   -k KEY, --key KEY     Data key. the value should be a list. None means the
#                         json file contains a list: ["..", ..]
#   -t THREAD, --thread THREAD
#                         The number of thread per each sell(default=10)
#   -p, --pipe            Dev only! pipe data from other modules(default=False)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used
#
# Examples:
# 	sentiment -j test.json -k data
# 	sentiment -j test.json -t 50
# Requirements:
# 	vaderSentiment

# %%
# !maryam -e sentiment -j russia.json -k 'results'
# Out:
# [*] negative
# [*] 	0.0
# [*] most neg sentence: 	{'t': 'ロシア - Wikipedia', 'a': 'https://www.bing.com/ck/a?!&&p=49700bc36f35d9ea6c635b546a172314a47805dd0ffda02d72902f569992a0f4JmltdHM9MTY1MzczMTE5NiZpZ3VpZD0xMTZmMGVkMi01ZmQ5LTQ1M2ItODY3OC02OGNhYWFjNWU5ZjUmaW5zaWQ9NTIxMg&ptn=3&fclid=103480b4-de6b-11ec-b7f6-b401fde992af&u=a1aHR0cHM6Ly9qYS53aWtpcGVkaWEub3JnL3dpa2kvJUUzJTgzJUFEJUUzJTgyJUI3JUUzJTgyJUEy&ntb=1', 'c': 'https://ja.wikipedia.org › wiki › ロシア', 'd': 'ロシア連邦 Российская Федерация       （国旗） （国章）  国の標語：なし 国歌： Госуда́рственный гимн Росси́йской Федера́ции（ロシア語） ロシア連邦国歌 （かつてのソビエト連邦の国歌の歌詞を変更したもの）     公用語  ロシア語    首都  モスクワ   最大の都市  モスクワ（ヨーロッパ州） ノヴォシビルスク（アジア州のシベリア地方） ハバロフスク（アジア州の極東地方）   政府       大統領  ウラジーミル・プーチン   連邦政府議長  ミハイル・ミシュスティン  安全保 …'}
# [*] neutral
# [*] 	47.0
# ...
