# %%
# !maryam -e searx --help
# Out:
# usage: searx [-h] -q QUERY [-l LIMIT] [--output] [--api] [--format]
#
# searx 0.1(Aman Singh) - description: Searx is a Privacy-respecting metasearch
# engine.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=1)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e searx -q cybersecurity
# Out:
# [*] [SEARX] Searching https://searx.prvcy.eu/search page 1...
# [*] Computer security
# [*] https://en.wikipedia.org/wiki/Computer_security
# [*] https://en.wikipedia.org › wiki › Computer_sec...
# [*] Computer security, cybersecurity (cyber security), or information technology security (IT security) is the protection of computer systems and networks from information disclosure, theft of, or damage to their hardware, software, or electronic data, as well as from the disruption or misdirection of the services they provide.. The field has become significant due to the expanded reliance on ...
#
# [*] What is Cybersecurity? | IBM
# [*] https://www.ibm.com/topics/cybersecurity
# [*] https://www.ibm.com › topics › cybersecur
# ...

# %%
# !maryam -e searx -q suryotrisongko --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "suryotrisongko - PPI Jepang Kumamoto",
#             "a": "https://ppij-kumamoto.org/author/suryotrisongko/",
#             "c": "https://ppij-kumamoto.org \u203a author \u203a suryotriso...",
#             "d": "suryotrisongko. Berita Menikmati Camping, Bbq, Air Terjun dan Pemandangan di Bumi Beruang Hitam. Banyak yang mimpi pengen punya pengalaman camping, tapi di Indonesia nggak ada temannya, atau mungkin khawatir masalah keamanan, atau khawatir masalah kebersihan toilet dll. Yuk kuliah ke Kumamoto dan nikmati pengalaman camping, yang aman, bersih ..."
#         },
#         {
#             "t": "Hatma Suryotrisongko | Live My Passion: Gairah, Kegemaran, Semangat ...",
#             "a": "https://hatmasuryotrisongko.wordpress.com/",
#             "c": "https://hatmasuryotrisongko.wordpress.com",
# ...
