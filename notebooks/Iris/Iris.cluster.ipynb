# %%
# !maryam -e google -q 'Marvel' -l 10 --api --format > test.json

# %%
# !cat test.json
# Out:
# {
#     "results": [
#         {
#             "t": "\u30de\u30fc\u30d9\u30eb\u516c\u5f0f\uff5cMarvel",
#             "a": "https://marvel.disney.co.jp/",
#             "c": "https://marvel.disney.co.jp",
#             "d": "\u30aa\u30fc\u30c7\u30a3\u30aa\u30c6\u30af\u30cb\u30ab\u304b\u3089\u300e\u30a2\u30d9\u30f3\u30b8\u30e3\u30fc\u30ba\uff0f\u30a8\u30f3\u30c9\u30b2\u30fc\u30e0\u300f\u306e\u4e16\u754c\u7684\u5927\u30d2\u30c3\u30c8\u3082\u8a18\u61b6\u306b\u65b0\u3057\u3044MARVEL\u306e\u30aa\u30ea\u30b8\u30ca\u30eb\u5b8c\u5168\u30ef\u30a4\u30e4\u30ec\u30b9\u30a4\u30e4\u30db\u30f3\u7b2c2\u5f3e\u304c\u767b\u5834\u3002 \u7b2c2\u5f3e\u306f\u3001\u5b8c\u5168\u65b0\u4f5c\u00a0...Amazon\uff1a e\u2606\u30a4\u30e4\u30db\u30f3\u30b1\u30fc\u30ba\u30c7\u30f3\u30ad\uff1a \u4e0a\u65b0\u96fb\u6a5f\u6771\u6025\u30cf\u30f3\u30ba\uff1a \u30ce\u30b8\u30de"
#         },
#         {
#             "t": "\u30ad\u30e3\u30e9\u30af\u30bf\u30fc\u7d39\u4ecb - \u30de\u30fc\u30d9\u30eb\u516c\u5f0f\uff5cMarvel",
# ...

# %%
# !maryam -e cluster --help
# Out:
# usage: cluster [-h] [-j JSON] [--output] [--api] [--format]
#
# cluster 0.1(Kaushik) - description: Cluster your data using kmeans and fp-
# growth.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -j JSON, --json JSON  Json file that contains the data
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e cluster
# Out:
# usage: cluster [-h] [-j JSON] [--output] [--api] [--format]
#
# cluster 0.1(Kaushik) - description: Cluster your data using kmeans and fp-
# growth.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -j JSON, --json JSON  Json file that contains the data
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used
#
# Examples:
# 	c
# 	l
# 	u
# 	s
# 	t
# 	e
# 	r
#
# 	-
# 	j
#
# 	t
# 	e
# 	s
# 	t
# 	.
# 	j
# 	s
# 	o
# 	n
# Requirements:
# 	sklearn
# 	kneed
# 	mlxtend
# 	numpy
# 	pandas

# %%
# !maryam -e cluster -j test.json
# Out:
# [*] Loading Data
# [*] Preprocessing
# [*] Clustering with KMeans
# /home/hatma/anaconda3/envs/tf/lib/python3.9/site-packages/maryam-2.5.1.post0-py3.9.egg/maryam/core/util/iris/cluster.py:88: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   km.fit(X)
# /home/hatma/anaconda3/envs/tf/lib/python3.9/site-packages/maryam-2.5.1.post0-py3.9.egg/maryam/core/util/iris/cluster.py:88: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   km.fit(X)
# /home/hatma/anaconda3/envs/tf/lib/python3.9/site-packages/maryam-2.5.1.post0-py3.9.egg/maryam/core/util/iris/cluster.py:88: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   km.fit(X)
# ...

# %%
# !maryam -e cluster -j test.json --output --api --format
# Out:
# /home/hatma/anaconda3/envs/tf/lib/python3.9/site-packages/maryam-2.5.1.post0-py3.9.egg/maryam/core/util/iris/cluster.py:88: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   km.fit(X)
# /home/hatma/anaconda3/envs/tf/lib/python3.9/site-packages/maryam-2.5.1.post0-py3.9.egg/maryam/core/util/iris/cluster.py:88: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   km.fit(X)
# /home/hatma/anaconda3/envs/tf/lib/python3.9/site-packages/maryam-2.5.1.post0-py3.9.egg/maryam/core/util/iris/cluster.py:88: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   km.fit(X)
# ...
