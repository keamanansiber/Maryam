# %%
# !maryam -e photon --help
# Out:
# usage: photon [-h] [-q QUERY] [-lat LATITUDE] [-lon LONGITUDE] [-l LIMIT]
#               [-e ENGINE] [-t THREAD] [--output] [--api] [--format]
#
# photon 1.0(Divya Goswami) - description: Search-as-you-type and typo tolerant
# geolocator. Works as reverse geocoder too.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Enter a location name
#   -lat LATITUDE, --latitude LATITUDE
#                         Enter latitude
#   -lon LONGITUDE, --longitude LONGITUDE
#                         Enter longitude
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of results, default=not set)
#   -e ENGINE, --engine ENGINE
#                         Engine used is photon
#   -t THREAD, --thread THREAD
#                         The number of engine that run per round(default=2)
#   --output, --output    Save the output to the workspace
# ...

# %%
# !maryam -e photon -q cybersecurity
# Out:
# [*] [PHOTON]Searching in photon.komoot.io...
# [*] Locality
# [*] Coordinates: [-111.93435019377236, 40.42819225]
# [*] United States, Intelligence Community Comprehensive National Cybersecurity Initiative Data Center
#
# [*] House
# [*] Coordinates: [77.6015215, 12.9319157]
# [*] Byrasandra Ward, India, Karnataka, Fireeye cybersecurity, Bangalore South, Swagath Road, Tilak Nagar
#
# [*] House
# [*] Coordinates: [-94.72493515022403, 32.4652164]
# [*] Longview, Harris Drive, Civil Engineering Lab/Cybersecurity Lab, Texas, Gregg County, United States
#
# [*] House
# [*] Coordinates: [-77.6803538, 43.0837217]
# [*] Global Cybersecurity Institute | RIT, Monroe County, Rochester, Lomb Memorial Drive, NY, United States
#
# [*] House
# [*] Coordinates: [101.6604784, 2.9180027]
# [*] Jalan Impact, Cyber 6, Cyberjaya, CyberSecurity Malaysia, Malaysia, Selangor
#
# [*] House
# [*] Coordinates: [23.784725389445033, 38.012028400000005]
# ...

# %%
# !maryam -e photon -q cybersecurity --output --api --format
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -111.93435019377236,
#                     40.42819225
#                 ],
#                 "type": "Point"
#             },
#             "type": "Feature",
#             "properties": {
#                 "osm_id": 158898045,
#                 "osm_type": "W",
#                 "extent": [
#                     -111.9409036,
#                     40.434012,
#                     -111.9255835,
#                     40.4204249
#                 ],
#                 "country": "United States",
#                 "osm_key": "landuse",
#                 "countrycode": "US",
#                 "osm_value": "military",
#                 "postcode": "84065",
#                 "name": "Intelligence Community Comprehensive National Cybersecurity Initiative Data Center",
#                 "type": "locality"
#             }
#         },
#         {
#             "geometry": {
# ...
