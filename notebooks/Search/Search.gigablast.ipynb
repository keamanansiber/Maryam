# %%
# !maryam -e gigablast --help
# Out:
# usage: gigablast [-h] -q QUERY [-l LIMIT] [--output] [--api] [--format]
#
# gigablast 0.1(Kaushik) - description: Gigablast provides large-scale, high-
# performance, real-time information retrieval technology and services for
# partner sites
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query to search
#   -l LIMIT, --limit LIMIT
#                         Max result count (default=15)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e gigablast -q cybersecurity
# Out:
# [*] Searching Gigablast...
# [*] Cybersecurity | Homeland Security
# [*] https://www.dhs.gov/topic/cybersecurity
# [*] https://www.dhs.gov › topic › cybersecuri
# [*] On November 16, 2018, President Trump signed into law the Cybersecurity and Infrastructure Security Agency Act of 2018.
# This landmark legislation elevates the mission of the former National Protection and Programs Directorate (NPPD) within DHS and establishes the Cybersecurity and Infrastructure Security Agency (CISA).
#
# [*] Home | Homeland Security
# [*] https://www.dhs.gov/
# [*] https://www.dhs.gov
# [*] Enhancing the nation's cybersecurity resilience is a top priority for DHS.
# Cybersecurity network icons floating on a black background.
#
# [*] Cybersecurity | Homeland Security
# [*] https://www.dhs.gov/cyber
# [*] https://www.dhs.gov › cyber
# [*] Cybersecurity.
# Subscribe to Cybersecurity news and updates.
#
# [*] Get Cybersecurity Safety Resources From the National Cyber Security Alliance
# ...

# %%
# !maryam -e gigablast -q suryotrisongko --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "Frontiers | Implementation of Synchronization Triggers in an open-source EEG system for Visual Evoked Potentials measurement",
#             "a": "https://www.frontiersin.org/10.3389/conf.fnhum.2016.220.00007/event_abstract",
#             "c": "https://www.frontiersin.org \u203a 10.3389 \u203a conf.fnhu...",
#             "d": "Suryotrisongko, H., & Samopa, F. (2015).   \nSuryotrisongko & Samopa, 2015)."
#         },
#         {
#             "t": "(PDF) Interactive Reading Using Low Cost Brain Computer Interfaces",
#             "a": "https://www.researchgate.net/publication/319947783_Interactive_Reading_Using_Low_Cost_Brain_Computer_Interfaces",
#             "c": "https://www.researchgate.net \u203a publication \u203a 31994...",
#             "d": "9. Suryotrisongko, H., Samopa, F.: Evaluating OpenBCI Spiderclaw V1 headwear ' s electrodes.   \nHatma Suryotrisongko."
#         },
#         {
# ...
