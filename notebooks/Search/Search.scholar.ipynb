# %%
# !maryam -e scholar --help
# Out:
# usage: scholar [-h] -q QUERY [-l LIMIT] [--output] [--api] [--format]
#
# scholar 0.1(Kaushik) - description: Google Scholar is a freely accessible web
# search engine that indexes scholarly literature across an array of publishing
# formats and disciplines.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Max result count (default=15)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e scholar -q cybersecurity
# Out:
# [*] Searching the scholar.google.com domain...
# [*] Defining cybersecurity
# [*] https://www.timreview.ca/article/835
# [*] D Craigen, N Diakun-Thibault, R Purse - Technology Innovation …, 2014 - timreview.ca
# [*] … review, we led multiple discussions on cybersecurity with a diverse group of practitioners, …
# of cybersecurity. In this article, we propose a resulting new definition: "Cybersecurity is the …
#
# [*] Cybersecurity: What everyone needs to know
# [*] https://books.google.com/books?hl=ko&lr=&id=f_lyDwAAQBAJ&oi=fnd&pg=PP1&dq=cybersecurity&ots=Dnp_XFDAop&sig=wOZ1CHX6Av0xvk2yISQYDJWgESI
# [*] PW Singer, A Friedman - 2014 - books.google.com
# [*] Dependence on computers has had a transformative effect on human society. Cybernetics
# is now woven into the core functions of virtually every basic institution, including our oldest …
#
# [*] Cybersecurity for industry 4.0
# [*] https://link.springer.com/content/pdf/10.1007/978-3-319-50660-9.pdf
# ...

# %%
# !maryam -e scholar -q suryotrisongko --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "Design and development of backend application for public complaint systems using microservice spring boot",
#             "a": "https://www.sciencedirect.com/science/article/pii/S1877050917329800",
#             "c": "H Suryotrisongko, DP Jayanto, A Tjahyanto\u00a0- Procedia Computer Science, 2017 - Elsevier",
#             "d": "E-government is an implementation of ICT (information and communication technologies) in \nthe field of governance in improving services to the public by a government or public sector. \u2026"
#         },
#         {
#             "t": "EEG wave identification in human brain with Emotiv EPOC for motor imagery",
#             "a": "https://www.sciencedirect.com/science/article/pii/S1877050915036017",
#             "c": "\u2026, E Riksakomara, H Suryotrisongko\u00a0- Procedia Computer\u00a0\u2026, 2015 - Elsevier",
# ...
