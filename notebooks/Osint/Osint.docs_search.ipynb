# %%
# !maryam -e docs_search --help
# Out:
# usage: docs_search [-h] -q QUERY -f FILE [-l LIMIT] [-c COUNT] [-s] -e ENGINES
#                    [-t THREAD] [--output] [--api] [--format]
#
# docs_search 0.8(Saeed) - description: Search in open-sources to find relevant
# documents. filetypes[pdf,doc,docx,ppt,pptx,xlsx,txt,..].
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Host Name, Company Name, keyword, query, etc
#   -f FILE, --file FILE  Filetype [pdf,doc,docx,ppt,pptx,xlsx,txt,..]
#   -l LIMIT, --limit LIMIT
#                         Search limit(number of pages, default=2)
#   -c COUNT, --count COUNT
#                         number of results per page(min=10)
#   -s, --site            If this is set, search just limited to the site
#   -e ENGINES, --engines ENGINES
#                         Search engines with comma separator
#   -t THREAD, --thread THREAD
#                         The number of engine that run per round(default=2)
# ...

# %%
# !maryam -e docs_search -q cybersecurity -f pdf -e google,bing,metacrawler
# Out:
# [*] [GOOGLE] Searching in 1 page...
# [*] [BING] Searching in 1 page...
# [!] [util/google:run_crawl] Google CAPTCHA triggered.
# [!] [util/page_parse:html_fromstring] Document is nil.
# [*] [METACRAWLER] Searching in 1 page...
# [*] [BING] Searching in 2 page...
# [*] [METACRAWLER] Searching in 2 page...
# [*] PDF
# ...

# %%
# !maryam -e docs_search -q suryotrisongko -f pdf -e google,bing,metacrawler  --output --api --format
# Out:
# {
#     "pdf": [
# ...
