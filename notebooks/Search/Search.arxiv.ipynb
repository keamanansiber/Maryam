# %%
# !maryam -e arxiv --help
# Out:
# usage: arxiv [-h] -q QUERY [-l LIMIT] [--output] [--api] [--format]
#
# arxiv 0.2(Kaushik) - description: ArXiv is a scientific research repository
# with a public API for searching its articles and papers
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Max page count (default=1)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e arxiv -q cybersecurity
# Out:
# [*] [ARXIV] Searching the arxiv.org domain...
# [*] Novel Approach for Cybersecurity Workforce Development: A Course in
#   Secure Design
# [*] http://arxiv.org/abs/1806.01198v1
# [*] Filipo Sharevski, Adam Trowbridge, Jessica Westbrook
# [*] Training the future cybersecurity workforce to respond to emerging threats
# requires introduction of novel educational interventions into the cybersecurity
# curriculum. To be effective, these interventions have to incorporate trending
# knowledge from cybersecurity and other related domains while allowing for
# experiential learning through hands-on experimentation. To date, the
# traditional interdisciplinary approach for cybersecurity training has infused
# political science, law, economics or linguistics knowledge into the
# cybersecurity curriculum, allowing for limited experimentation. Cybersecurity
# students were left with little opportunity to acquire knowledge, skills, and
# ...

# %%
# !maryam -e arxiv -q cybersecurity --output --api --format
# Out:
# {
#     "results": [
#         {
#             "t": "Novel Approach for Cybersecurity Workforce Development: A Course in\n  Secure Design",
#             "a": "http://arxiv.org/abs/1806.01198v1",
#             "c": "Filipo Sharevski, Adam Trowbridge, Jessica Westbrook",
# ...
