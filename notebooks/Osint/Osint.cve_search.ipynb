# %%
# !maryam -e cve_search --help
# Out:
# usage: cve_search [-h] -q QUERY [-e ENGINES] [-c COUNT] [-t THREAD] [--output]
#                   [--api] [--format]
#
# cve_search 0.3(Dimitrios Papageorgiou) - description: Search in open-sources
# to find CVEs(exploits, vulns).
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -e ENGINES, --engines ENGINES
#                         DB source to search. e.g mitre,...(default=mitre)
#   -c COUNT, --count COUNT
#                         Number of results per search(default=20, -1 for all
#                         available)
#   -t THREAD, --thread THREAD
#                         The number of engine that run per round(default=2)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e cve_search -q wordpress
# Out:
# [*] [MITRE] Searching in mitre...
# [*] CVE-2022-29451
# [*] https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29451
# [*] Cross-Site Request Forgery (CSRF) leading to Arbitrary File Upload vulnerability in Rara One Click Demo Import plugin &lt;= 1.2.9 on WordPress allows attackers to trick logged-in admin users into uploading dangerous files into /wp-content/uploads/ directory.
#
# [*] CVE-2022-29449
# [*] https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29449
# [*] Authenticated (contributor or higher user role) Stored Cross-Site Scripting (XSS) vulnerability in Opal Hotel Room Booking plugin &lt;= 1.2.7 at WordPress.
#
# [*] CVE-2022-29448
# [*] https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29448
# [*] Authenticated (admin or higher user role) Local File Inclusion (LFI) vulnerability in Wow-Company's Herd Effects plugin &lt;= 5.2 at WordPress.
#
# [*] CVE-2022-29447
# [*] https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29447
# ...

# %%
# !maryam -e cve_search -q wordpress --output --api --format
# Out:
# {
#     "exploits": [
#         [
#             "CVE-2022-29451",
#             "https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29451",
#             "Cross-Site Request Forgery (CSRF) leading to Arbitrary File Upload vulnerability in Rara One Click Demo Import plugin &lt;= 1.2.9 on WordPress allows attackers to trick logged-in admin users into uploading dangerous files into /wp-content/uploads/ directory."
#         ],
#         [
#             "CVE-2022-29449",
#             "https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29449",
#             "Authenticated (contributor or higher user role) Stored Cross-Site Scripting (XSS) vulnerability in Opal Hotel Room Booking plugin &lt;= 1.2.7 at WordPress."
#         ],
#         [
#             "CVE-2022-29448",
#             "https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2022-29448",
# ...
