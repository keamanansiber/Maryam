# %%
# !maryam -e dark_web_crawler --help
# Out:
# usage: dark_web_crawler [-h] -q QUERY [-d DEPTH] [-t THREADS] [--output]
#                         [--api] [--format]
#
# dark_web_crawler 0.1(Kaushik) - description: A Dark Web Crawler that uses Best
# First Snowball Sampling
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Comma separated query strings
#   -d DEPTH, --depth DEPTH
#                         Scraper depth level
#   -t THREADS, --threads THREADS
#                         The number of workers
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e dark_web_crawler -q cybersecurity
# Out:
# [*] Grabbing results from Phobos
# [*] Grabbing results from Ahmia
# No links found in http://grwp24hodrefzvjjuccrkw3mjq4tzhaaq32amf33dzpmuxe7ilepcmad.onion/channel/UCpVfkl5HVLU6XUM_YB_1ulQ94m[*] [*] [*]
# No links found in http://dnhuboxyxgbhmnozl5j4wntoon56x423iteusfmbqwsdwl26gnqqy6id.onion/articles?filter=cybersecuritym[*]
# http://ridv6h7uyozosljv5umlcf6paoq72rcfpka7pigkje2xg5gqmig5lxyd.onion/online/golang-cybersecurity.html took too long to respond
# http://dftm66z6zh6dvn4imjhtcdoxcy5syjy57d36umh6ydwlnad3padc3zid.onion/read-blog/3_cybersecurity-companies-data-has-been-exposed-on-dark-web.html took too long to respond
# No links found in http://lpiyu33yusoalp5kh3f4hak2so2sjjvjw5ykyvu2dulzosgvuffq6sad.onion/workshops/Access-Granted-Hollywood-Hacking-Sampler
# http://protonmailrmez3lotccipshtkleegetolb73fuirgj7r4o4vfu7ozyd.onion/       ozwy7oa3d4tdsuaousy36ntw4sid.onion/[*]
# http://hxuzjtocnzvv5g2rtg2bhwkcbupmk7rclb6lly3fo4tvqkk5oyrv3nid.onion/
# ...

# %%
# !maryam -e dark_web_crawler -q indonesia
# Out:
# [*] Grabbing results from Phobos
# [*] Grabbing results from Ahmia
# http://invest2qbmqua3fyveu3makh4hfnsxe6vm7r2x3ewwpegmhl2rhatlyd.onion/http-bitcoin/index16.htmlwcbqhembyd.onion/...[*] [*] [*] [*] [*]
# http://invest3phrbggaczhejwyrneyxwgujo6u7e5w6jtcbakstmnk3ru67yd.onion/all-cryptocurrency/index7.html
# http://invest3phrbggaczhejwyrneyxwgujo6u7e5w6jtcbakstmnk3ru67yd.onion/wm-bitcoin/index12.html
# http://invest2esyu34y64dcsuor2asc757tr26iwyvr355zsfqm2jhozy4xqd.onion/blitz-bitcoin/index29.html
# http://invest3phrbggaczhejwyrneyxwgujo6u7e5w6jtcbakstmnk3ru67yd.onion/exchanges-bitcoin/index13.html
# http://invest2vq6uqprhj3fqwm2aox5ll75svpqo6zgmabn52vs4h2ri5guid.onion/bitcoin-best/index12.html
# http://invest2j4pg52c3ba2i2s45ocpjlpoc6zeqrlv6qemta7lqxpleyp5id.onion
# http://invest3phrbggaczhejwyrneyxwgujo6u7e5w6jtcbakstmnk3ru67yd.onion/bitcoin-conveyor/index11.html
# http://invest3phrbggaczhejwyrneyxwgujo6u7e5w6jtcbakstmnk3ru67yd.onion/accept-bitcoin/index26.html
# ...

# %%
# !maryam -e dark_web_crawler -q "owasp maryam" --output --api --format
# Out:
# {
#     "1": [
#         "http://grwp24hodrefzvjjuccrkw3mjq4tzhaaq32amf33dzpmuxe7ilepcmad.onion/watch?v=JdmLUlYSz2I - "
#     ],
#     "running_errors": []
# }
