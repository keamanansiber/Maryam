# %%
# !maryam -e sepiasearch --help
# Out:
# usage: sepiasearch [-h] -q QUERY [-l LIMIT] [--output] [--api] [--format]
#
# sepiasearch 0.1(Rishabh Jain) - description: Sepia Search is a video search
# engine optimized for PeerTube channels.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   -l LIMIT, --limit LIMIT
#                         Max result count (default=15)
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e sepiasearch -q cybersecurity
# Out:
# [*] [SEPIASEARCH] Extracting Data From API
# [*] TOTAL RESULTS
# [*] 	279
# [*] RESULTS
# [*] 	TITLE
# [*] 		Cyber4Growth - Innovation & Cybersecurity
# [*] 	AUTHOR
# [*] 		SECURITYMADEIN.LU
# [*] 	URL
# [*] 		https://peertube.securitymadein.lu/videos/watch/aae75fe7-9606-4439-9eb7-a05e5534946d
# [*] 	LENGTH
# [*] 		0:44:57 hours
# [*] 	THUMBNAIL
# [*] 		https://peertube.securitymadein.lu/static/thumbnails/aae75fe7-9606-4439-9eb7-a05e5534946d.jpg
# [*] 	EMBEDED URL
# [*] 		https://peertube.securitymadein.lu/videos/embed/aae75fe7-9606-4439-9eb7-a05e5534946d
# [*] 	PUBLISHED DATE
# [*] 		2021-11-11T14:08:37.786Z
#
# [*] 	TITLE
# [*] 		Cybersecurity Career Roadmap
# [*] 	AUTHOR
# [*] 		Sam Winston
# [*] 	URL
# [*] 		https://peertube.su/videos/watch/5a7fc940-8c11-4c6f-86e3-0b62a25cb95c
# [*] 	LENGTH
# [*] 		0:23:42 hours
# [*] 	THUMBNAIL
# [*] 		https://peertube.su/static/thumbnails/4b6fc122-35bb-4c9c-84ab-e6b6e292e600.jpg
# [*] 	EMBEDED URL
# ...

# %%
# !maryam -e sepiasearch -q hatma --output --api --format
# Out:
# {
#     "Total Results": 38,
#     "results": [
#         {
#             "Title": "The British Union of Fascists - Fatma Nur",
#             "Author": "Roland BAUDUIN",
#             "URL": "https://tube-nantes.beta.education.fr/videos/watch/b8e030a1-e7e2-40c1-ac43-4b32aba749af",
#             "Length": "0:3:36 hours",
#             "Thumbnail": "https://tube-nantes.beta.education.fr/static/thumbnails/b8e030a1-e7e2-40c1-ac43-4b32aba749af.jpg",
#             "Embeded URL": "https://tube-nantes.beta.education.fr/videos/embed/b8e030a1-e7e2-40c1-ac43-4b32aba749af",
#             "Published Date": "2021-05-27T15:50:50.884Z"
#         },
#         {
#             "Title": "F\u00e5r mimistrar hata och hota meningsmotst\u00e5ndare?",
#             "Author": "Hakan Bergmarks kanal",
#             "URL": "https://swebbtube.se/videos/watch/03d0e71f-4be4-44cb-be35-4fbfa3c6e558",
#             "Length": "0:2:2 hours",
# ...
