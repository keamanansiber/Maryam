# %%
# !maryam -e openstreetmap --help
# Out:
# usage: openstreetmap [-h] -q QUERY [--output] [--api] [--format]
#
# openstreetmap 0.1(Kunal Khandelwal) - description: OpenStreetMap is the free
# wiki world map
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -q QUERY, --query QUERY
#                         Query string
#   --output, --output    Save the output to the workspace
#   --api, --api          Show results in the JSON format
#   --format, --format    Beautifying JSON output if --api is used

# %%
# !maryam -e openstreetmap -q cybersecurity
# Out:
# [*] Searching openstreetmap...
#
# [*] Military Area
# [*] Intelligence Community Comprehensive National Cybersecurity Initiative Data Center, Bluffdale, Lehi, Salt Lake County, Utah, 84065, United States
# [*] 40.42819225, -111.93435019377236
# [*] https://www.openstreetmap.org/way/158898045
#
# [*] Governmental Office
# [*] ENISA, 1, Βασιλίσσης Σοφίας, Σωρός, Δήμος Αμαρουσίου, Περιφερειακή Ενότητα Βορείου Τομέα Αθηνών, Περιφέρεια Αττικής, Αποκεντρωμένη Διοίκηση Αττικής, 15124, Ελλάς
# [*] 38.0505556, 23.8084173
# [*] https://www.openstreetmap.org/node/6969339365
#
# [*] Governmental Office
# [*] ENISA, 95, Νικόλαου Πλαστήρα, Κοινότητα Βουτών, Δημοτική Ενότητα Ηρακλείου, Δήμος Ηρακλείου, Περιφερειακή Ενότητα Ηρακλείου, Περιφέρεια Κρήτης, Αποκεντρωμένη Διοίκηση Κρήτης, 71005, Ελλάς
# [*] 35.30759515, 25.077373980485667
# [*] https://www.openstreetmap.org/relation/11178783
#
# [*] Company
# ...

# %%
# !maryam -e openstreetmap -q security --output --api --format
# Out:
# {
#     "results": [
#         {
#             "category": "",
#             "location": "Residence of Interior Security",
#             "latitude": "17.58269",
#             "longitude": "44.24412",
#             "link": "https://www.openstreetmap.org/#map=12/17.58269/44.24412"
#         },
#         {
#             "category": "",
#             "location": "Security-Widefield",
#             "latitude": "38.74728",
#             "longitude": "-104.71439",
#             "link": "https://www.openstreetmap.org/#map=12/38.74728/-104.71439"
#         },
#         {
#             "category": "",
#             "location": "Public Security - Aqaba Police Station",
#             "latitude": "29.52676",
#             "longitude": "35.00589",
#             "link": "https://www.openstreetmap.org/#map=12/29.52676/35.00589"
#         },
#         {
#             "category": "",
#             "location": "Public Security Directorate",
#             "latitude": "32.03124",
# ...
